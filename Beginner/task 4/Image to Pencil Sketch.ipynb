# %% [markdown]
# # Data Science Intern at Let's Grow More LGMVIP Feb-22
#
# ### Beginner Level Task
#
# ### Image to Pencil Sketch with Python:
#
#     We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.
#
#
# ### Sanskriti Jain

# %%
from IPython import display
from IPython.display import Image

# %%
Image(url="https://cdn1.vectorstock.com/i/1000x1000/37/90/close-up-of-colorful-eyes-cat-vector-23633790.jpg", width=874, height=652)
# Out:
# <img src="https://cdn1.vectorstock.com/i/1000x1000/37/90/close-up-of-colorful-eyes-cat-vector-23633790.jpg" width="874" height="652"/>

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_path = "H://Internship//Lets Grow More//Image to Sketch//resized img1.jpg"
filename = 'resized img1.jpg'
#type of imagepath
type(img_path)
# Out:
# str

# %%
# Read in the image
img = cv2.imread(img_path)

# %%
grey_filter = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.waitKey(0)
# Out:
# -1

# %%
#Invert the image
invert = cv2.bitwise_not(grey_filter)

# %%
#Blur the image by gussian function
blur = cv2.GaussianBlur(invert, (21,21),0)

# %%
#using bitwise_not function to inevrt the image
invertedblur = cv2.bitwise_not(blur)

# %%
#sketch filter function
sketch_filter = cv2.divide(grey_filter, invertedblur, scale=256.0)

# %%
#Sketch filter output image
cv2.imwrite("output.png", sketch_filter)
# Out:
# True

# %%
#original image and the pencil sketch
invertedblur = 255 - blur

# %%
sketch_filter = cv2.divide(grey_filter, invertedblur, scale=256.0)

# %%
cv2.imshow("output.png", sketch_filter)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# show the image
cv2.imshow("original image", img)
cv2.imshow("sketch_filter", sketch_filter)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
